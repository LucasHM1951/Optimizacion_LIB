# %% [markdown]
# # Coeficiente de Arrastre con PySR

# %%
## Importando Librerias 
import numpy as np
import pandas as pd
from pysr import PySRRegressor
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

# %% [markdown]
# ### Cargando datos

# %%
# cargando datos

# importacion de DF
file_path = 'D:\\CODES\\LIB_SR\\Dataset_coeficientes\\df_cdrag_25.txt'
df_cdrag_25 = pd.read_csv(file_path, delimiter=',')

file_path = 'D:\\CODES\\LIB_SR\\Dataset_coeficientes\\df_cdrag_53.txt'
df_cdrag_53 = pd.read_csv(file_path, delimiter=',')

file_path = 'D:\\CODES\\LIB_SR\\Dataset_coeficientes\\df_cdrag_74.txt'
df_cdrag_74 = pd.read_csv(file_path, delimiter=',')

file_path = 'D:\\CODES\\LIB_SR\\Dataset_coeficientes\\df_cdrag_102.txt'
df_cdrag_102 = pd.read_csv(file_path, delimiter=',')

# %%
# definiendo conjuntos de train y test

# definiendo conjunto de train
df_cdrag_train = pd.concat([df_cdrag_25, df_cdrag_74], ignore_index=True)

# separando entre x e y
y_train = df_cdrag_train.drop(columns=['Current','K','Flujo','t_viento','Diametro','col_fluido','col_celda','n_fluido','n_celda','Rem','colIndex'])
X_train = df_cdrag_train.drop(columns=['Current','Flujo','t_viento','Diametro','col_fluido','col_celda','n_fluido',
                                    'n_celda','colIndex','cdrag'])


# definiendo conjunto de test

y_test = df_cdrag_53.drop(columns=['Current','K','Flujo','t_viento','Diametro','col_fluido','col_celda','n_fluido','n_celda','Rem','colIndex'])
X_test = df_cdrag_53.drop(columns=['Current','Flujo','t_viento','Diametro','col_fluido','col_celda','n_fluido',
                                    'n_celda','colIndex','cdrag'])


# renombrando
X_train.rename(columns={'Rem':'Re'}, inplace=True)
X_test.rename(columns={'Rem':'Re'}, inplace=True)

# %% [markdown]
# ### Entrenando Modelo

# %%
model = PySRRegressor(
    niterations=20,
    binary_operators=["+", "-", "*", "/", "pow"],
    unary_operators=[],
    population_size=200,
    verbosity=1,
    maxsize=12,
    parsimony=1e-3,
    progress=True
)

model.fit(X_train, y_train)
# Out:
# d:\env\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# d:\env\lib\site-packages\pysr\sr.py:2029: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://astroautomata.com/PySR/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# d:\env\lib\site-packages\pysr\sr.py:73: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 0.000e+00
# Head worker occupation: 0.0%
# Progress: 0 / 300 total iterations (0.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.220e+01
# Head worker occupation: 0.0%
# Progress: 1 / 300 total iterations (0.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           2.420e-01  5.314e+00  y = 1.4701 / K
# 5           2.853e-02  1.069e+00  y = (K - -0.73896) / K
# 7           1.974e-02  1.841e-01  y = ((K - -0.44692) / K) * 1.2488
# 9           1.974e-02  5.126e-05  y = ((K - (K * -0.24826)) - -0.55744) / K
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.470e+03
# Head worker occupation: 4.8%
# Progress: 5 / 300 total iterations (1.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.170e-02  5.314e+00  y = 1.76 / 0.94012
# 5           2.041e-02  7.512e-01  y = (-0.87435 * K) + 2.7511
# 7           1.828e-02  5.519e-02  y = (2.05 / (K ^ 0.33487)) - 0.22591
# 9           1.827e-02  2.784e-04  y = (2.3435 / (K ^ (0.5573 * 0.53083))) - 0.51805
# 11          1.794e-02  8.909e-03  y = (((K / 0.36339) ^ (K / 0.89579)) ^ -1.4052) + 1.5936
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.410e+03
# Head worker occupation: 2.3%
# Progress: 6 / 300 total iterations (2.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.170e-02  5.314e+00  y = 1.76 / 0.94012
# 5           2.041e-02  7.512e-01  y = (-0.87435 * K) + 2.7511
# 7           1.828e-02  5.519e-02  y = (2.05 / (K ^ 0.33487)) - 0.22591
# 9           1.827e-02  2.784e-04  y = (2.3435 / (K ^ (0.5573 * 0.53083))) - 0.51805
# 11          1.375e-02  1.419e-01  y = 1.6149 + ((((12.046 / K) * 43.373) / Re) ^ K)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.380e+03
# Head worker occupation: 4.5%
# Progress: 8 / 300 total iterations (2.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.170e-02  5.314e+00  y = 1.76 / 0.94012
# 5           2.041e-02  7.512e-01  y = (-0.87435 * K) + 2.7511
# 7           1.828e-02  5.519e-02  y = (2.05 / (K ^ 0.33487)) - 0.22591
# 9           1.827e-02  2.784e-04  y = (2.3435 / (K ^ (0.5573 * 0.53083))) - 0.51805
# 11          1.375e-02  1.419e-01  y = 1.6149 + ((((12.046 / K) * 43.373) / Re) ^ K)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.440e+03
# Head worker occupation: 4.9%
# Progress: 10 / 300 total iterations (3.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.170e-02  5.314e+00  y = 1.76 / 0.94012
# 5           2.041e-02  7.512e-01  y = (-0.87435 * K) + 2.7511
# 7           1.828e-02  5.519e-02  y = (2.05 / (K ^ 0.33487)) - 0.22591
# 9           1.827e-02  2.784e-04  y = (2.3435 / (K ^ (0.5573 * 0.53083))) - 0.51805
# 11          1.375e-02  1.419e-01  y = 1.6149 + ((((12.046 / K) * 43.373) / Re) ^ K)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.470e+03
# Head worker occupation: 3.3%
# Progress: 12 / 300 total iterations (4.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.170e-02  5.314e+00  y = 1.76 / 0.94012
# 5           2.041e-02  7.512e-01  y = (-0.87435 * K) + 2.7511
# 7           1.828e-02  5.519e-02  y = (2.05 / (K ^ 0.33487)) - 0.22591
# 9           1.827e-02  2.784e-04  y = (2.3435 / (K ^ (0.5573 * 0.53083))) - 0.51805
# 11          1.003e-02  3.000e-01  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.680e+03
# Head worker occupation: 3.7%
# Progress: 16 / 300 total iterations (5.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.170e-02  5.314e+00  y = 1.76 / 0.94012
# 5           1.860e-02  7.978e-01  y = (K ^ -0.62795) - -0.81555
# 7           1.828e-02  8.633e-03  y = (2.05 / (K ^ 0.33487)) - 0.22591
# 9           1.827e-02  2.784e-04  y = (2.3435 / (K ^ (0.5573 * 0.53083))) - 0.51805
# 11          1.003e-02  3.000e-01  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.730e+03
# Head worker occupation: 3.1%
# Progress: 18 / 300 total iterations (6.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 10.338 / 5.4356
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62795) - -0.81555
# 7           1.828e-02  8.633e-03  y = (2.05 / (K ^ 0.33487)) - 0.22591
# 9           1.827e-02  2.784e-04  y = (2.3435 / (K ^ (0.5573 * 0.53083))) - 0.51805
# 11          1.003e-02  3.000e-01  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.750e+03
# Head worker occupation: 2.6%
# Progress: 19 / 300 total iterations (6.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 10.338 / 5.4356
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62795) - -0.81555
# 7           1.828e-02  8.633e-03  y = (2.05 / (K ^ 0.33487)) - 0.22591
# 9           1.827e-02  2.784e-04  y = (2.3435 / (K ^ (0.5573 * 0.53083))) - 0.51805
# 11          1.003e-02  3.000e-01  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.880e+03
# Head worker occupation: 2.4%
# Progress: 22 / 300 total iterations (7.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           3.676e-02  1.747e+00  y = 2.7511 - K
# 5           1.860e-02  3.407e-01  y = (K ^ -0.62795) - -0.81555
# 7           1.828e-02  8.633e-03  y = (2.05 / (K ^ 0.33487)) - 0.22591
# 9           1.818e-02  2.680e-03  y = (1.3823 / ((K + 0.40605) ^ 0.99254)) + 0.83712
# 11          1.003e-02  2.976e-01  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.350e+03
# Head worker occupation: 2.1%
# Progress: 25 / 300 total iterations (8.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           2.186e-02  2.007e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 11          1.003e-02  9.870e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.330e+03
# Head worker occupation: 2.0%
# Progress: 29 / 300 total iterations (9.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           2.186e-02  2.007e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 11          1.003e-02  9.870e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.390e+03
# Head worker occupation: 1.7%
# Progress: 33 / 300 total iterations (11.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           2.186e-02  2.007e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 11          1.003e-02  9.870e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.520e+03
# Head worker occupation: 1.5%
# Progress: 36 / 300 total iterations (12.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           2.186e-02  2.007e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 11          1.003e-02  9.870e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.560e+03
# Head worker occupation: 1.3%
# Progress: 37 / 300 total iterations (12.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           2.186e-02  2.007e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 11          1.003e-02  9.870e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.440e+03
# Head worker occupation: 1.2%
# Progress: 39 / 300 total iterations (13.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           2.186e-02  2.007e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 11          1.003e-02  9.870e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.720e+03
# Head worker occupation: 1.1%
# Progress: 41 / 300 total iterations (13.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           2.186e-02  2.007e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.170e-02  1.201e-01  y = (3.0087 + (-4.0329e-05 * Re)) - (K ^ 0.74678)
# 11          1.003e-02  7.731e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.920e+03
# Head worker occupation: 1.0%
# Progress: 43 / 300 total iterations (14.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           2.186e-02  2.007e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.070e+03
# Head worker occupation: 1.0%
# Progress: 46 / 300 total iterations (15.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.578e-01  1.594e+01  y = 1.0852
# 3           2.186e-02  1.773e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.970e+03
# Head worker occupation: 0.9%
# Progress: 47 / 300 total iterations (15.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.578e-01  1.594e+01  y = 1.0852
# 3           2.186e-02  1.773e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.410e+03
# Head worker occupation: 0.9%
# Progress: 49 / 300 total iterations (16.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.578e-01  1.594e+01  y = 1.0852
# 3           2.186e-02  1.773e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.040e+03
# Head worker occupation: 1.2%
# Progress: 52 / 300 total iterations (17.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.300e+03
# Head worker occupation: 1.1%
# Progress: 56 / 300 total iterations (18.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.300e+03
# Head worker occupation: 1.1%
# Progress: 59 / 300 total iterations (19.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.210e+03
# Head worker occupation: 1.0%
# Progress: 60 / 300 total iterations (20.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.120e+03
# Head worker occupation: 1.0%
# Progress: 61 / 300 total iterations (20.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.250e+03
# Head worker occupation: 1.0%
# Progress: 65 / 300 total iterations (21.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.260e+03
# Head worker occupation: 1.0%
# Progress: 66 / 300 total iterations (22.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.190e+03
# Head worker occupation: 1.0%
# Progress: 68 / 300 total iterations (22.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.100e+03
# Head worker occupation: 1.0%
# Progress: 70 / 300 total iterations (23.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.150e+03
# Head worker occupation: 1.6%
# Progress: 73 / 300 total iterations (24.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.150e+03
# Head worker occupation: 1.6%
# Progress: 75 / 300 total iterations (25.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.250e+03
# Head worker occupation: 1.6%
# Progress: 78 / 300 total iterations (26.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.440e-01  1.594e+01  y = 1.0937
# 3           2.186e-02  1.764e+00  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.900e+03
# Head worker occupation: 1.6%
# Progress: 80 / 300 total iterations (26.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.850e+03
# Head worker occupation: 1.7%
# Progress: 82 / 300 total iterations (27.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.840e+03
# Head worker occupation: 1.7%
# Progress: 85 / 300 total iterations (28.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.770e+03
# Head worker occupation: 1.7%
# Progress: 89 / 300 total iterations (29.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.800e+03
# Head worker occupation: 1.6%
# Progress: 91 / 300 total iterations (30.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.810e+03
# Head worker occupation: 1.6%
# Progress: 92 / 300 total iterations (30.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.850e+03
# Head worker occupation: 1.6%
# Progress: 95 / 300 total iterations (31.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.820e+03
# Head worker occupation: 1.5%
# Progress: 97 / 300 total iterations (32.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.850e+03
# Head worker occupation: 1.5%
# Progress: 98 / 300 total iterations (32.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.640e+03
# Head worker occupation: 1.5%
# Progress: 101 / 300 total iterations (33.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# 11          1.003e-02  7.152e-02  y = (K ^ (0.67117 * -0.88777)) + ((-4.534e-05 * Re) - -0.97407...
#                                   )
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.680e+03
# Head worker occupation: 1.5%
# Progress: 102 / 300 total iterations (34.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.125e-02  1.594e+01  y = 1.8808
# 3           2.186e-02  7.144e-01  y = 2.8731 - K
# 5           1.860e-02  8.097e-02  y = (K ^ -0.62795) - -0.81555
# 7           1.488e-02  1.115e-01  y = ((-4.0329e-05 * Re) + 3.0087) - K
# 9           1.157e-02  1.259e-01  y = ((-4.0329e-05 * Re) + 3.0087) - (K ^ 0.80205)
# ...
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.258e-07  y = ((-4.4646e-05 * (Re - K)) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.360e+03
# Head worker occupation: 1.1%
# Progress: 262 / 300 total iterations (87.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.258e-07  y = ((-4.4646e-05 * (Re - K)) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.390e+03
# Head worker occupation: 1.1%
# Progress: 265 / 300 total iterations (88.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.258e-07  y = ((-4.4646e-05 * (Re - K)) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.380e+03
# Head worker occupation: 1.1%
# Progress: 267 / 300 total iterations (89.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.410e+03
# Head worker occupation: 1.1%
# Progress: 271 / 300 total iterations (90.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.220e+03
# Head worker occupation: 1.1%
# Progress: 274 / 300 total iterations (91.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.210e+03
# Head worker occupation: 1.3%
# Progress: 276 / 300 total iterations (92.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.090e+03
# Head worker occupation: 1.5%
# Progress: 279 / 300 total iterations (93.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+03
# Head worker occupation: 1.4%
# Progress: 280 / 300 total iterations (93.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.080e+03
# Head worker occupation: 1.4%
# Progress: 283 / 300 total iterations (94.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.970e+03
# Head worker occupation: 1.4%
# Progress: 285 / 300 total iterations (95.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.940e+03
# Head worker occupation: 1.4%
# Progress: 289 / 300 total iterations (96.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.960e+03
# Head worker occupation: 1.4%
# Progress: 293 / 300 total iterations (97.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.920e+03
# Head worker occupation: 1.4%
# Progress: 296 / 300 total iterations (98.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.960e+03
# Head worker occupation: 1.4%
# Progress: 299 / 300 total iterations (99.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 3           2.186e-02  7.120e-01  y = 2.8731 - K
# 5           1.829e-02  8.915e-02  y = 1.823 * (K ^ -0.37246)
# 7           1.488e-02  1.033e-01  y = (3.0086 - K) + (-4.0316e-05 * Re)
# 9           9.468e-03  2.260e-01  y = ((-4.4643e-05 * Re) - -1.9768) * (K ^ -0.34892)
# 11          9.468e-03  6.855e-07  y = (((Re - K) * -4.4643e-05) - -1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	   pick         score                                           equation  \
# 	0        0.000000e+00                                          1.9019274
# 	1        7.119589e-01                                      2.8730948 - K
# 	2        8.915279e-02                      1.8230312 * (K ^ -0.37245628)
# 	3        1.033141e-01               (3.00863 - K) + (-4.0316354e-5 * Re)
# 	4  >>>>  2.259772e-01  ((-4.4643166e-5 * Re) - -1.9767536) * (K ^ -0....
# 	5        7.392998e-07  (((Re - K) * -4.464311e-5) - -1.9767032) * (K ...
#
# 	       loss  complexity
# 	0  0.090810           1
# 	1  0.021864           3
# 	2  0.018293           5
# 	3  0.014878           7
# 	4  0.009468           9
# 	5  0.009468          11
# ]

# %%
print(model)
# Out:
# PySRRegressor.equations_ = [
# 	   pick         score                                           equation  \
# 	0        0.000000e+00                                          1.9019274
# 	1        7.119589e-01                                      2.8730948 - K
# 	2        8.915279e-02                      1.8230312 * (K ^ -0.37245628)
# 	3        1.033141e-01               (3.00863 - K) + (-4.0316354e-5 * Re)
# 	4  >>>>  2.259772e-01  ((-4.4643166e-5 * Re) - -1.9767536) * (K ^ -0....
# 	5        7.392998e-07  (((Re - K) * -4.464311e-5) - -1.9767032) * (K ...
#
# 	       loss  complexity
# 	0  0.090810           1
# 	1  0.021864           3
# 	2  0.018293           5
# 	3  0.014878           7
# 	4  0.009468           9
# 	5  0.009468          11
# ]

# %%
best_equation = model.equations_.iloc[4]['equation']
print(best_equation)
# Out:
# ((-4.4643166e-5 * Re) - -1.9767536) * (K ^ -0.34891888)

# %%
y_pred = model.predict(X_test)

# %%
# comparar con modelo de Rafael


def cdrag(S, Re):
    return S**(-0.6) + 5*Re**(-0.23)

def cdrag_gp(S, Re):
    return ((-4.4643166e-5 * Re) - -1.9767536) * (S **( -0.34891888))

# %%
# Calcular cdrag_pred y cdrag_gp_pred en vectores separados
cdrag_pred = X_test.apply(lambda row: cdrag(row['K'], row['Re']), axis=1).values
cdrag_gp_pred = X_test.apply(lambda row: cdrag_gp(row['K'], row['Re']), axis=1).values

# Calcular R^2 y MSE para cdrag
r2_cdrag = r2_score(y_test['cdrag'], cdrag_pred)
mse_cdrag = mean_squared_error(y_test['cdrag'], cdrag_pred)

# Calcular MAE y MAPE para cdrag
mae_cdrag = mean_absolute_error(y_test['cdrag'], cdrag_pred)
mape_cdrag = mean_absolute_percentage_error(y_test['cdrag'], cdrag_pred)

# Calcular R^2 y MSE para cdrag_gp
r2_cdrag_gp = r2_score(y_test['cdrag'], cdrag_gp_pred)
mse_cdrag_gp = mean_squared_error(y_test['cdrag'], cdrag_gp_pred)

# Calcular MAE y MAPE para cdrag_gp
mae_cdrag_gp = mean_absolute_error(y_test['cdrag'], cdrag_gp_pred)
mape_cdrag_gp = mean_absolute_percentage_error(y_test['cdrag'], cdrag_gp_pred)

#  Mostrar Metricas 

print(f"R^2 cdrag original: {r2_cdrag}, R^2 cdrag GPLearn: {r2_cdrag_gp} ")
print(f"MSE cdrag original: {mse_cdrag}, MSE cdrag GPLearn: {mse_cdrag_gp} ")
print(f"MAE cdrag original: {mae_cdrag}, MAE cdrag GPLearn: {mae_cdrag_gp} ")
print(f"MAPE cdrag original: {mape_cdrag*100}*100, MAPE cdrag GPLearn: {mape_cdrag_gp*100}*100 ")
# Out:
# R^2 cdrag original: 0.8904926780136748, R^2 cdrag GPLearn: 0.900584838387332
# MSE cdrag original: 0.011588230963563853, MSE cdrag GPLearn: 0.010520263240402195
# MAE cdrag original: 0.07580331737181549, MAE cdrag GPLearn: 0.07454400166450104
# MAPE cdrag original: 3.7448292462961463*100, MAPE cdrag GPLearn: 3.723570512405093*100

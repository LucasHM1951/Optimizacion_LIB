# %% [markdown]
# # Coeficiente de Arrastre con PySR

# %%
## Importando Librerias 
import numpy as np
import pandas as pd
from pysr import PySRRegressor
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# ### Cargando datos

# %%
# cargando datos

# importacion de DF
file_path = 'D:\\CODES\\LIB_SR\\Dataset_coeficientes\\df_cdrag_25.txt'
df_cdrag_25 = pd.read_csv(file_path, delimiter=',')

file_path = 'D:\\CODES\\LIB_SR\\Dataset_coeficientes\\df_cdrag_53.txt'
df_cdrag_53 = pd.read_csv(file_path, delimiter=',')

file_path = 'D:\\CODES\\LIB_SR\\Dataset_coeficientes\\df_cdrag_74.txt'
df_cdrag_74 = pd.read_csv(file_path, delimiter=',')

file_path = 'D:\\CODES\\LIB_SR\\Dataset_coeficientes\\df_cdrag_102.txt'
df_cdrag_102 = pd.read_csv(file_path, delimiter=',')

# %%
# definiendo conjuntos de train y test

# definiendo conjunto de train
df_cdrag_train = pd.concat([df_cdrag_25, df_cdrag_74], ignore_index=True)

# separando entre x e y
y_train = df_cdrag_train.drop(columns=['Current','K','Flujo','t_viento','Diametro','col_fluido','col_celda','n_fluido','n_celda','Rem','colIndex'])
X_train = df_cdrag_train.drop(columns=['Current','Flujo','t_viento','Diametro','col_fluido','col_celda','n_fluido',
                                    'n_celda','colIndex','cdrag'])


# definiendo conjunto de test

y_test = df_cdrag_53.drop(columns=['Current','K','Flujo','t_viento','Diametro','col_fluido','col_celda','n_fluido','n_celda','Rem','colIndex'])
X_test = df_cdrag_53.drop(columns=['Current','Flujo','t_viento','Diametro','col_fluido','col_celda','n_fluido',
                                    'n_celda','colIndex','cdrag'])


# renombrando
X_train.rename(columns={'Rem':'Re'}, inplace=True)
X_test.rename(columns={'Rem':'Re'}, inplace=True)

# %% [markdown]
# ### Entrenando Modelo

# %%
model = PySRRegressor(
    niterations=100,
    binary_operators=["+", "*", "pow"],
    unary_operators=[],
    population_size=200,
    verbosity=1,
    maxsize=12,
    parsimony=1e-3,
    progress=True
)

model.fit(X_train, y_train)
# Out:
# d:\env\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# d:\env\lib\site-packages\pysr\sr.py:2029: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://astroautomata.com/PySR/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# d:\env\lib\site-packages\pysr\sr.py:73: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 0.000e+00
# Head worker occupation: 0.0%
# Progress: 0 / 1500 total iterations (0.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 0.000e+00
# Head worker occupation: 0.0%
# Progress: 0 / 1500 total iterations (0.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.480e+02
# Head worker occupation: 0.0%
# Progress: 1 / 1500 total iterations (0.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           1.134e-01  5.314e+00  y = 1.2962 + 0.75618
# 5           5.712e-02  3.430e-01  y = 1.2962 + (0.66341 ^ K)
# 7           1.972e-02  5.318e-01  y = (0.21408 ^ (K * K)) + 1.6134
# 11          1.808e-02  2.175e-02  y = 1.6943 + (((2.6483 ^ K) ^ (K * K)) ^ -3.0263)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.710e+02
# Head worker occupation: NaN%
# Progress: 2 / 1500 total iterations (0.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           1.134e-01  5.314e+00  y = 1.2962 + 0.75618
# 5           5.712e-02  3.430e-01  y = 1.2962 + (0.66341 ^ K)
# 7           1.972e-02  5.318e-01  y = (0.21408 ^ (K * K)) + 1.6134
# 9           1.656e-02  8.743e-02  y = ((Re ^ -0.1845) ^ (K * K)) + 1.5998
# 11          1.571e-02  2.608e-02  y = ((Re ^ -0.31419) ^ ((-0.22643 + K) * K)) + 1.646
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.890e+02
# Head worker occupation: 2.4%
# Progress: 6 / 1500 total iterations (0.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.296e-02  5.314e+00  y = 1.1238 + 0.73183
# 5           3.204e-02  5.325e-01  y = 0.77702 + (K ^ -0.84033)
# 7           1.860e-02  2.721e-01  y = ((K ^ 0.77599) ^ -0.80919) + 0.81557
# 9           1.656e-02  5.807e-02  y = ((Re ^ -0.1845) ^ (K * K)) + 1.5998
# 11          1.571e-02  2.608e-02  y = ((Re ^ -0.31419) ^ ((-0.22643 + K) * K)) + 1.646
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.620e+02
# Head worker occupation: 1.2%
# Progress: 7 / 1500 total iterations (0.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.081e-02  5.314e+00  y = 0.79065 + 1.1113
# 5           2.041e-02  7.464e-01  y = 2.7511 + (-0.87435 * K)
# 7           1.860e-02  4.656e-02  y = ((K ^ 0.77599) ^ -0.80919) + 0.81557
# 9           1.182e-02  2.265e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.420e+02
# Head worker occupation: 1.1%
# Progress: 10 / 1500 total iterations (0.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.081e-02  5.314e+00  y = 0.79065 + 1.1113
# 5           2.041e-02  7.464e-01  y = 2.7511 + (-0.87435 * K)
# 7           1.860e-02  4.656e-02  y = ((K ^ 0.77599) ^ -0.80919) + 0.81557
# 9           1.182e-02  2.265e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.970e+02
# Head worker occupation: 1.2%
# Progress: 12 / 1500 total iterations (0.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           2.041e-02  7.464e-01  y = 2.7511 + (-0.87435 * K)
# 7           1.828e-02  5.520e-02  y = 1.1383 + ((0.35189 + K) ^ -1.2867)
# 9           1.182e-02  2.179e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.570e+02
# Head worker occupation: 1.0%
# Progress: 15 / 1500 total iterations (1.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62793) + 0.81558
# 7           1.828e-02  8.638e-03  y = 1.1383 + ((0.35189 + K) ^ -1.2867)
# 9           1.182e-02  2.179e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.440e+02
# Head worker occupation: 0.9%
# Progress: 17 / 1500 total iterations (1.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62793) + 0.81558
# 7           1.825e-02  9.370e-03  y = 1.3453 + ((0.20857 ^ K) * 2.2557)
# 9           1.182e-02  2.171e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.450e+03
# Head worker occupation: 0.8%
# Progress: 21 / 1500 total iterations (1.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62793) + 0.81558
# 7           1.825e-02  9.370e-03  y = 1.3453 + ((0.20857 ^ K) * 2.2557)
# 9           1.182e-02  2.171e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.430e+03
# Head worker occupation: 0.8%
# Progress: 23 / 1500 total iterations (1.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62793) + 0.81558
# 7           1.825e-02  9.370e-03  y = 1.3453 + ((0.20857 ^ K) * 2.2557)
# 9           1.182e-02  2.171e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.640e+03
# Head worker occupation: 0.7%
# Progress: 25 / 1500 total iterations (1.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62793) + 0.81558
# 7           1.825e-02  9.370e-03  y = 1.3453 + ((0.20857 ^ K) * 2.2557)
# 9           1.182e-02  2.171e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.670e+03
# Head worker occupation: 0.7%
# Progress: 26 / 1500 total iterations (1.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62793) + 0.81558
# 7           1.825e-02  9.370e-03  y = 1.3453 + ((0.20857 ^ K) * 2.2557)
# 9           1.182e-02  2.171e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.690e+03
# Head worker occupation: 0.6%
# Progress: 27 / 1500 total iterations (1.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62793) + 0.81558
# 7           1.820e-02  1.065e-02  y = ((0.20557 ^ K) + 1.2457) ^ 1.6104
# 9           1.182e-02  2.158e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.720e+03
# Head worker occupation: 0.6%
# Progress: 28 / 1500 total iterations (1.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.860e-02  7.929e-01  y = (K ^ -0.62793) + 0.81558
# 7           1.820e-02  1.065e-02  y = ((0.20557 ^ K) + 1.2457) ^ 1.6104
# 9           1.182e-02  2.158e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.710e+03
# Head worker occupation: 0.5%
# Progress: 29 / 1500 total iterations (1.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = (K ^ -0.37246) * 1.823
# 7           1.820e-02  2.462e-03  y = ((0.20557 ^ K) + 1.2457) ^ 1.6104
# 9           1.182e-02  2.158e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.850e+03
# Head worker occupation: 0.5%
# Progress: 32 / 1500 total iterations (2.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.182e-02  2.119e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.820e+03
# Head worker occupation: 0.5%
# Progress: 33 / 1500 total iterations (2.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.182e-02  2.119e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.960e+03
# Head worker occupation: 0.4%
# Progress: 36 / 1500 total iterations (2.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.182e-02  2.119e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.010e+03
# Head worker occupation: 0.4%
# Progress: 39 / 1500 total iterations (2.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.182e-02  2.119e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.940e+03
# Head worker occupation: 0.4%
# Progress: 41 / 1500 total iterations (2.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.182e-02  2.119e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.940e+03
# Head worker occupation: 0.4%
# Progress: 42 / 1500 total iterations (2.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.182e-02  2.119e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.890e+03
# Head worker occupation: 0.4%
# Progress: 45 / 1500 total iterations (3.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.182e-02  2.119e-01  y = 1.4203 + (2.323 * ((Re ^ -0.2238) ^ K))
# 11          1.048e-02  6.014e-02  y = K + (3.999 * (((K * Re) ^ -0.20995) ^ K))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.590e+03
# Head worker occupation: 0.3%
# Progress: 47 / 1500 total iterations (3.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.540e+03
# Head worker occupation: 0.3%
# Progress: 50 / 1500 total iterations (3.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.640e+03
# Head worker occupation: 0.3%
# Progress: 53 / 1500 total iterations (3.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.640e+03
# Head worker occupation: 0.3%
# Progress: 54 / 1500 total iterations (3.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.640e+03
# Head worker occupation: 0.3%
# Progress: 55 / 1500 total iterations (3.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.690e+03
# Head worker occupation: 0.3%
# Progress: 57 / 1500 total iterations (3.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 3           9.081e-02  1.295e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.720e+03
# Head worker occupation: 0.3%
# Progress: 58 / 1500 total iterations (3.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.170e+00  1.594e+01  y = 0.86316
# 3           9.081e-02  1.278e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.790e+03
# Head worker occupation: 0.3%
# Progress: 61 / 1500 total iterations (4.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.170e+00  1.594e+01  y = 0.86316
# 3           9.081e-02  1.278e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.860e+03
# Head worker occupation: 0.3%
# Progress: 63 / 1500 total iterations (4.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.170e+00  1.594e+01  y = 0.86316
# 3           9.081e-02  1.278e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.820e+03
# Head worker occupation: 0.2%
# Progress: 64 / 1500 total iterations (4.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.170e+00  1.594e+01  y = 0.86316
# 3           9.081e-02  1.278e+00  y = 0.79065 + 1.1113
# 5           1.829e-02  8.011e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.806e-02  6.428e-03  y = 1.4823 + (0.1337 ^ (K + -0.44209))
# 9           1.003e-02  2.943e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.210e+03
# Head worker occupation: 0.2%
# Progress: 68 / 1500 total iterations (4.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.340e+03
# Head worker occupation: 0.2%
# Progress: 70 / 1500 total iterations (4.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.750e+03
# Head worker occupation: 0.3%
# Progress: 74 / 1500 total iterations (4.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.050e+03
# Head worker occupation: 0.3%
# Progress: 77 / 1500 total iterations (5.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.190e+03
# Head worker occupation: 0.3%
# Progress: 79 / 1500 total iterations (5.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.670e+03
# Head worker occupation: 0.3%
# Progress: 82 / 1500 total iterations (5.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.760e+03
# Head worker occupation: 0.4%
# Progress: 85 / 1500 total iterations (5.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.190e+03
# Head worker occupation: 0.5%
# Progress: 91 / 1500 total iterations (6.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.460e+03
# Head worker occupation: 0.5%
# Progress: 94 / 1500 total iterations (6.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.500e+03
# Head worker occupation: 0.5%
# Progress: 97 / 1500 total iterations (6.467%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.700e+03
# Head worker occupation: 0.5%
# Progress: 100 / 1500 total iterations (6.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.570e+03
# Head worker occupation: 0.5%
# Progress: 103 / 1500 total iterations (6.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.510e+03
# Head worker occupation: 0.6%
# Progress: 105 / 1500 total iterations (7.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.350e+03
# Head worker occupation: 0.6%
# Progress: 107 / 1500 total iterations (7.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.360e+03
# Head worker occupation: 0.6%
# Progress: 109 / 1500 total iterations (7.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = 1.823 * (K ^ -0.37246)
# 7           1.659e-02  4.899e-02  y = (Re ^ -0.02636) + (K ^ -0.62729)
# 9           1.003e-02  2.517e-01  y = ((K ^ -0.59585) + 0.97407) + (-4.534e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.080e+03
# Head worker occupation: 0.6%
# Progress: 112 / 1500 total iterations (7.467%)
# ====================================================================================================
# Hall of Fame:
# ...
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.530e+03
# Head worker occupation: 0.3%
# Progress: 1464 / 1500 total iterations (97.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.780e+03
# Head worker occupation: 0.3%
# Progress: 1467 / 1500 total iterations (97.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.920e+03
# Head worker occupation: 0.3%
# Progress: 1470 / 1500 total iterations (98.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.970e+03
# Head worker occupation: 0.3%
# Progress: 1471 / 1500 total iterations (98.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.770e+03
# Head worker occupation: 0.3%
# Progress: 1472 / 1500 total iterations (98.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.450e+03
# Head worker occupation: 0.3%
# Progress: 1475 / 1500 total iterations (98.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.540e+03
# Head worker occupation: 0.3%
# Progress: 1478 / 1500 total iterations (98.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.610e+03
# Head worker occupation: 0.3%
# Progress: 1481 / 1500 total iterations (98.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.640e+03
# Head worker occupation: 0.3%
# Progress: 1483 / 1500 total iterations (98.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.760e+03
# Head worker occupation: 0.3%
# Progress: 1486 / 1500 total iterations (99.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.680e+03
# Head worker occupation: 0.3%
# Progress: 1487 / 1500 total iterations (99.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.690e+03
# Head worker occupation: 0.3%
# Progress: 1490 / 1500 total iterations (99.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.540e+03
# Head worker occupation: 0.3%
# Progress: 1493 / 1500 total iterations (99.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.450e+03
# Head worker occupation: 0.3%
# Progress: 1497 / 1500 total iterations (99.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.250e+03
# Head worker occupation: 0.3%
# Progress: 1499 / 1500 total iterations (99.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.9019
# 5           1.829e-02  4.006e-01  y = (K ^ -0.37246) * 1.823
# 7           1.198e-02  2.116e-01  y = 3.3238 ^ ((Re ^ K) ^ -0.08592)
# 9           9.306e-03  1.263e-01  y = 7.933 ^ ((Re ^ -0.15627) ^ (K ^ 0.46174))
# 11          9.294e-03  6.289e-04  y = 6.3577 ^ ((Re ^ -0.14172) ^ (K ^ (Re ^ -0.084111)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          1.9019274
# 	1        0.400556                      (K ^ -0.37246224) * 1.8230331
# 	2  >>>>  0.211634               3.3237665 ^ ((Re ^ K) ^ -0.08592033)
# 	3        0.126313  7.9330106 ^ ((Re ^ -0.15626507) ^ (K ^ 0.46173...
# 	4        0.000629  6.357708 ^ ((Re ^ -0.14172447) ^ (K ^ (Re ^ -0...
#
# 	       loss  complexity
# 	0  0.090810           1
# 	1  0.018293           5
# 	2  0.011980           7
# 	3  0.009306           9
# 	4  0.009294          11
# ]

# %%
print(model)
# Out:
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          1.9019274
# 	1        0.400556                      (K ^ -0.37246224) * 1.8230331
# 	2  >>>>  0.211634               3.3237665 ^ ((Re ^ K) ^ -0.08592033)
# 	3        0.126313  7.9330106 ^ ((Re ^ -0.15626507) ^ (K ^ 0.46173...
# 	4        0.000629  6.357708 ^ ((Re ^ -0.14172447) ^ (K ^ (Re ^ -0...
#
# 	       loss  complexity
# 	0  0.090810           1
# 	1  0.018293           5
# 	2  0.011980           7
# 	3  0.009306           9
# 	4  0.009294          11
# ]

# %%
best_equation = model.equations_.iloc[1]['equation']
print(best_equation)
# Out:
# (K ^ -0.37246224) * 1.8230331

# %%
best_equation = model.equations_.iloc[2]['equation']
print(best_equation)
# Out:
# 3.3237665 ^ ((Re ^ K) ^ -0.08592033)

# %%
best_equation = model.equations_.iloc[3]['equation']
print(best_equation)
# Out:
# 7.9330106 ^ ((Re ^ -0.15626507) ^ (K ^ 0.46173513))

# %%
best_equation = model.equations_.iloc[4]['equation']
print(best_equation)
# Out:
# 6.357708 ^ ((Re ^ -0.14172447) ^ (K ^ (Re ^ -0.0841106)))

# %%
# Predecir en los datos de prueba
y_pred = model.predict(X_test)

# Calcular métricas
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("R^2:", r2)
# Out:
# MSE: 0.01224172618467844
# R^2: 0.8843172305428634

# %%
# comparar con modelo de Rafael


def cdrag(S, Re):
    return S**(-0.6) + 5*Re**(-0.23)

def cdrag_gp(S, Re):
    return 3.3237665 ** ((Re ** S) **( -0.08592033))

# %%
# Calcular cdrag_pred y cdrag_gp_pred en vectores separados
cdrag_pred = X_test.apply(lambda row: cdrag(row['K'], row['Re']), axis=1).values
cdrag_gp_pred = X_test.apply(lambda row: cdrag_gp(row['K'], row['Re']), axis=1).values

# Calcular R^2 y MSE para cdrag
r2_cdrag = r2_score(y_test['cdrag'], cdrag_pred)
mse_cdrag = mean_squared_error(y_test['cdrag'], cdrag_pred)

# Calcular MAE y MAPE para cdrag
mae_cdrag = mean_absolute_error(y_test['cdrag'], cdrag_pred)
mape_cdrag = mean_absolute_percentage_error(y_test['cdrag'], cdrag_pred)

# Calcular R^2 y MSE para cdrag_gp
r2_cdrag_gp = r2_score(y_test['cdrag'], cdrag_gp_pred)
mse_cdrag_gp = mean_squared_error(y_test['cdrag'], cdrag_gp_pred)

# Calcular MAE y MAPE para cdrag_gp
mae_cdrag_gp = mean_absolute_error(y_test['cdrag'], cdrag_gp_pred)
mape_cdrag_gp = mean_absolute_percentage_error(y_test['cdrag'], cdrag_gp_pred)

#  Mostrar Metricas 

print(f"R^2 cdrag original: {r2_cdrag}, R^2 cdrag GPLearn: {r2_cdrag_gp} ")
print(f"MSE cdrag original: {mse_cdrag}, MSE cdrag GPLearn: {mse_cdrag_gp} ")
print(f"MAE cdrag original: {mae_cdrag}, MAE cdrag GPLearn: {mae_cdrag_gp} ")
print(f"MAPE cdrag original: {mape_cdrag*100}*100, MAPE cdrag GPLearn: {mape_cdrag_gp*100}*100 ")
# Out:
# R^2 cdrag original: 0.8904926780136748, R^2 cdrag GPLearn: 0.8843172305428634
# MSE cdrag original: 0.011588230963563853, MSE cdrag GPLearn: 0.01224172618467844
# MAE cdrag original: 0.07580331737181549, MAE cdrag GPLearn: 0.08036105069354246
# MAPE cdrag original: 3.7448292462961463*100, MAPE cdrag GPLearn: 4.078423927875645*100

# %%
# con otra ecuacion

def cdrag(S, Re):
    return S**(-0.6) + 5*Re**(-0.23)

def cdrag_gp(S, Re):
    return 7.9330106 ** ((Re **( -0.15626507)) ** (S ** 0.46173513))

# %%
# Calcular cdrag_pred y cdrag_gp_pred en vectores separados
cdrag_pred = X_test.apply(lambda row: cdrag(row['K'], row['Re']), axis=1).values
cdrag_gp_pred = X_test.apply(lambda row: cdrag_gp(row['K'], row['Re']), axis=1).values

# Calcular R^2 y MSE para cdrag
r2_cdrag = r2_score(y_test['cdrag'], cdrag_pred)
mse_cdrag = mean_squared_error(y_test['cdrag'], cdrag_pred)

# Calcular MAE y MAPE para cdrag
mae_cdrag = mean_absolute_error(y_test['cdrag'], cdrag_pred)
mape_cdrag = mean_absolute_percentage_error(y_test['cdrag'], cdrag_pred)

# Calcular R^2 y MSE para cdrag_gp
r2_cdrag_gp = r2_score(y_test['cdrag'], cdrag_gp_pred)
mse_cdrag_gp = mean_squared_error(y_test['cdrag'], cdrag_gp_pred)

# Calcular MAE y MAPE para cdrag_gp
mae_cdrag_gp = mean_absolute_error(y_test['cdrag'], cdrag_gp_pred)
mape_cdrag_gp = mean_absolute_percentage_error(y_test['cdrag'], cdrag_gp_pred)

#  Mostrar Metricas 

print(f"R^2 cdrag original: {r2_cdrag}, R^2 cdrag GPLearn: {r2_cdrag_gp} ")
print(f"MSE cdrag original: {mse_cdrag}, MSE cdrag GPLearn: {mse_cdrag_gp} ")
print(f"MAE cdrag original: {mae_cdrag}, MAE cdrag GPLearn: {mae_cdrag_gp} ")
print(f"MAPE cdrag original: {mape_cdrag*100}*100, MAPE cdrag GPLearn: {mape_cdrag_gp*100}*100 ")
# Out:
# R^2 cdrag original: 0.8904926780136748, R^2 cdrag GPLearn: 0.8985614818058523
# MSE cdrag original: 0.011588230963563853, MSE cdrag GPLearn: 0.01073437790381038
# MAE cdrag original: 0.07580331737181549, MAE cdrag GPLearn: 0.07489537395626014
# MAPE cdrag original: 3.7448292462961463*100, MAPE cdrag GPLearn: 3.753179528461591*100

# %%
# otra ecuacion

def cdrag(S, Re):
    return S**(-0.6) + 5*Re**(-0.23)

def cdrag_gp(S, Re):
    return 7.9330106 ** ((Re **( -0.15626507)) ** (S ** 0.46173513))

# %%
# Calcular cdrag_pred y cdrag_gp_pred en vectores separados
cdrag_pred = X_test.apply(lambda row: cdrag(row['K'], row['Re']), axis=1).values
cdrag_gp_pred = X_test.apply(lambda row: cdrag_gp(row['K'], row['Re']), axis=1).values

# Calcular R^2 y MSE para cdrag
r2_cdrag = r2_score(y_test['cdrag'], cdrag_pred)
mse_cdrag = mean_squared_error(y_test['cdrag'], cdrag_pred)

# Calcular MAE y MAPE para cdrag
mae_cdrag = mean_absolute_error(y_test['cdrag'], cdrag_pred)
mape_cdrag = mean_absolute_percentage_error(y_test['cdrag'], cdrag_pred)

# Calcular R^2 y MSE para cdrag_gp
r2_cdrag_gp = r2_score(y_test['cdrag'], cdrag_gp_pred)
mse_cdrag_gp = mean_squared_error(y_test['cdrag'], cdrag_gp_pred)

# Calcular MAE y MAPE para cdrag_gp
mae_cdrag_gp = mean_absolute_error(y_test['cdrag'], cdrag_gp_pred)
mape_cdrag_gp = mean_absolute_percentage_error(y_test['cdrag'], cdrag_gp_pred)

#  Mostrar Metricas 

print(f"R^2 cdrag original: {r2_cdrag}, R^2 cdrag GPLearn: {r2_cdrag_gp} ")
print(f"MSE cdrag original: {mse_cdrag}, MSE cdrag GPLearn: {mse_cdrag_gp} ")
print(f"MAE cdrag original: {mae_cdrag}, MAE cdrag GPLearn: {mae_cdrag_gp} ")
print(f"MAPE cdrag original: {mape_cdrag*100}*100, MAPE cdrag GPLearn: {mape_cdrag_gp*100}*100 ")
# Out:
# R^2 cdrag original: 0.8904926780136748, R^2 cdrag GPLearn: 0.8985614818058523
# MSE cdrag original: 0.011588230963563853, MSE cdrag GPLearn: 0.01073437790381038
# MAE cdrag original: 0.07580331737181549, MAE cdrag GPLearn: 0.07489537395626014
# MAPE cdrag original: 3.7448292462961463*100, MAPE cdrag GPLearn: 3.753179528461591*100

# %% [markdown]
# ### Entrenamiento del Modelo V2

# %%
model = PySRRegressor(
    niterations=50,
    binary_operators=["+","-","*" ,"/", "^"],
    unary_operators=[],
    population_size=200,
    verbosity=1,
    maxsize=15,
    parsimony=1e-3,
    constraints={'^':(2,1)},
    nested_constraints={'^':{'^':0}},
    complexity_of_variables = 2,
    random_state = 0,
    progress=True
)

model.fit(X_train, y_train)
# Out:
# d:\env\lib\site-packages\pysr\sr.py:1310: UserWarning: Note: Setting `random_state` without also setting `deterministic` to True and `procs` to 0 will result in non-deterministic searches.
#   warnings.warn(
# d:\env\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# d:\env\lib\site-packages\pysr\sr.py:2029: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://astroautomata.com/PySR/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 0.000e+00
# Head worker occupation: 0.0%
# Progress: 0 / 750 total iterations (0.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.060e+03
# Head worker occupation: 25.1%
# Progress: 5 / 750 total iterations (0.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.097e-02  5.314e+00  y = 0.63242 ^ -1.4173
# 5           9.086e-02  5.737e-04  y = (0.63242 ^ -1.4173) - 0.0053141
# 6           2.249e-02  1.396e+00  y = 1.3811 + (0.44806 / K)
# 8           1.829e-02  1.034e-01  y = (1.3481 / (K ^ 0.37246)) * 1.3523
# 14          1.824e-02  5.000e-04  y = ((Re / Re) - (-1.8532 / (K + 0.4716))) * 0.81058
# 15          1.194e-02  4.234e-01  y = ((1.1495 - (K + -0.85863)) / 1.2285) - ((4.5775e-05 * Re) ...
#                                   - 1.2108)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.580e+03
# Head worker occupation: 14.0%
# Progress: 9 / 750 total iterations (1.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.097e-02  5.314e+00  y = 0.63242 ^ -1.4173
# 5           9.085e-02  6.347e-04  y = (1.3996 - -0.57175) + -0.063132
# 6           2.041e-02  1.493e+00  y = (-0.87433 * K) + 2.751
# 8           1.829e-02  5.475e-02  y = (1.3481 / (K ^ 0.37246)) * 1.3523
# 9           1.790e-02  2.184e-02  y = (Re ^ -0.032142) + (K ^ -0.66756)
# 11          1.493e-02  9.082e-02  y = (K ^ -0.60543) + (0.29619 + (Re ^ -0.079964))
# 13          1.457e-02  1.206e-02  y = (K ^ -0.6151) + ((Re ^ -0.12428) + (0.41971 * 1.0598))
# 15          1.194e-02  9.938e-02  y = ((1.1495 - (K + -0.85863)) / 1.2285) - ((4.5775e-05 * Re) ...
#                                   - 1.2108)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.010e+03
# Head worker occupation: 11.0%
# Progress: 10 / 750 total iterations (1.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.097e-02  5.314e+00  y = 0.63242 ^ -1.4173
# 5           9.085e-02  6.350e-04  y = 1.0672 * (0.39283 ^ -0.62199)
# 6           2.041e-02  1.493e+00  y = (-0.87433 * K) + 2.751
# 8           1.829e-02  5.475e-02  y = (1.3481 / (K ^ 0.37246)) * 1.3523
# 9           1.790e-02  2.184e-02  y = (Re ^ -0.032142) + (K ^ -0.66756)
# 11          1.493e-02  9.082e-02  y = (K ^ -0.60543) + (0.29619 + (Re ^ -0.079964))
# 13          1.457e-02  1.206e-02  y = (K ^ -0.6151) + ((Re ^ -0.12428) + (0.41971 * 1.0598))
# 15          1.194e-02  9.938e-02  y = ((1.1495 - (K + -0.85863)) / 1.2285) - ((4.5775e-05 * Re) ...
#                                   - 1.2108)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.440e+03
# Head worker occupation: 4.7%
# Progress: 14 / 750 total iterations (1.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.097e-02  5.314e+00  y = 0.63242 ^ -1.4173
# 5           9.081e-02  8.557e-04  y = 2.4931 + (1.0758 * -0.54949)
# 6           2.041e-02  1.493e+00  y = (-0.87433 * K) + 2.751
# 8           1.829e-02  5.482e-02  y = (2.0133 / (K + 0.65558)) - -0.61433
# 9           1.790e-02  2.169e-02  y = (Re ^ -0.032142) + (K ^ -0.66756)
# 11          1.493e-02  9.082e-02  y = (K ^ -0.60543) + (0.29619 + (Re ^ -0.079964))
# 13          1.457e-02  1.206e-02  y = (K ^ -0.6151) + ((Re ^ -0.12428) + (0.41971 * 1.0598))
# 15          1.194e-02  9.938e-02  y = ((1.1495 - (K + -0.85863)) / 1.2285) - ((4.5775e-05 * Re) ...
#                                   - 1.2108)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.100e+03
# Head worker occupation: 3.5%
# Progress: 15 / 750 total iterations (2.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           9.097e-02  5.314e+00  y = 0.63242 ^ -1.4173
# 5           9.081e-02  8.557e-04  y = 2.4931 + (1.0758 * -0.54949)
# 6           2.041e-02  1.493e+00  y = (-0.87433 * K) + 2.751
# 8           1.829e-02  5.482e-02  y = (2.0133 / (K + 0.65558)) - -0.61433
# 9           1.790e-02  2.169e-02  y = (Re ^ -0.032142) + (K ^ -0.66756)
# 11          1.493e-02  9.082e-02  y = (K ^ -0.60543) + (0.29619 + (Re ^ -0.079964))
# 13          1.457e-02  1.206e-02  y = (K ^ -0.6151) + ((Re ^ -0.12428) + (0.41971 * 1.0598))
# 15          1.194e-02  9.938e-02  y = ((1.1495 - (K + -0.85863)) / 1.2285) - ((4.5775e-05 * Re) ...
#                                   - 1.2108)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.510e+03
# Head worker occupation: 4.1%
# Progress: 22 / 750 total iterations (2.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.004e+00  1.594e+01  y = -0.52977
# 3           9.081e-02  2.096e+00  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.829e-02  7.448e-05  y = (2.0133 / (K + 0.65558)) - -0.61433
# 9           1.488e-02  2.065e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 13          1.457e-02  5.240e-03  y = (K ^ -0.6151) + ((Re ^ -0.12428) + (0.41971 * 1.0598))
# 15          1.194e-02  9.938e-02  y = ((1.1495 - (K + -0.85863)) / 1.2285) - ((4.5775e-05 * Re) ...
#                                   - 1.2108)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.280e+03
# Head worker occupation: 4.0%
# Progress: 23 / 750 total iterations (3.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.004e+00  1.594e+01  y = -0.52977
# 3           9.081e-02  2.096e+00  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.829e-02  7.448e-05  y = (2.0133 / (K + 0.65558)) - -0.61433
# 9           1.488e-02  2.065e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          1.374e-02  3.981e-02  y = ((Re ^ -0.11758) + (K ^ -0.48548)) / 0.7568
# 15          1.194e-02  3.503e-02  y = ((1.1495 - (K + -0.85863)) / 1.2285) - ((4.5775e-05 * Re) ...
#                                   - 1.2108)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.080e+03
# Head worker occupation: 4.8%
# Progress: 29 / 750 total iterations (3.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.004e+00  1.594e+01  y = -0.52977
# 2           1.210e+00  1.602e+00  y = K
# 3           9.081e-02  2.590e+00  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.829e-02  7.448e-05  y = (2.0133 / (K + 0.65558)) - -0.61433
# 9           1.488e-02  2.065e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          1.094e-02  1.537e-01  y = (1.4433 - (-0.52282 / K)) + (-4.5947e-05 * Re)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.180e+03
# Head worker occupation: 4.7%
# Progress: 30 / 750 total iterations (4.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.004e+00  1.594e+01  y = -0.52977
# 2           1.210e+00  1.602e+00  y = K
# 3           9.081e-02  2.590e+00  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.829e-02  7.448e-05  y = (2.0133 / (K + 0.65558)) - -0.61433
# 9           1.488e-02  2.065e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          1.003e-02  1.974e-01  y = (K ^ -0.59584) + ((-4.5341e-05 * Re) + 0.97408)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.330e+03
# Head worker occupation: 5.8%
# Progress: 32 / 750 total iterations (4.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           6.004e+00  1.594e+01  y = -0.52977
# 2           1.210e+00  1.602e+00  y = K
# 3           9.081e-02  2.590e+00  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.829e-02  7.448e-05  y = (2.0133 / (K + 0.65558)) - -0.61433
# 9           1.488e-02  2.065e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          1.003e-02  1.974e-01  y = (K ^ -0.59584) + ((-4.5341e-05 * Re) + 0.97408)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.400e+03
# Head worker occupation: 6.8%
# Progress: 36 / 750 total iterations (4.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.829e-02  7.448e-05  y = (2.0133 / (K + 0.65558)) - -0.61433
# 9           1.488e-02  2.065e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          1.003e-02  1.974e-01  y = (K ^ -0.59584) + ((-4.5341e-05 * Re) + 0.97408)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.230e+03
# Head worker occupation: 6.9%
# Progress: 38 / 750 total iterations (5.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.829e-02  7.448e-05  y = (2.0133 / (K + 0.65558)) - -0.61433
# 9           1.488e-02  2.065e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          1.003e-02  1.974e-01  y = (K ^ -0.59584) + ((-4.5341e-05 * Re) + 0.97408)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.490e+03
# Head worker occupation: 7.3%
# Progress: 44 / 750 total iterations (5.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  6.535e-04  y = ((K ^ -0.30896) * 2.2361) + -0.41104
# 9           1.488e-02  2.053e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          1.003e-02  1.974e-01  y = (K ^ -0.59584) + ((-4.5341e-05 * Re) + 0.97408)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.620e+03
# Head worker occupation: 7.7%
# Progress: 50 / 750 total iterations (6.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  6.535e-04  y = ((K ^ -0.30896) * 2.2361) + -0.41104
# 9           1.488e-02  2.053e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.660e+03
# Head worker occupation: 7.0%
# Progress: 52 / 750 total iterations (6.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  6.535e-04  y = ((K ^ -0.30896) * 2.2361) + -0.41104
# 9           1.488e-02  2.053e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.310e+03
# Head worker occupation: 6.6%
# Progress: 54 / 750 total iterations (7.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  6.535e-04  y = ((K ^ -0.30896) * 2.2361) + -0.41104
# 9           1.488e-02  2.053e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.920e+03
# Head worker occupation: 6.4%
# Progress: 59 / 750 total iterations (7.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  6.535e-04  y = ((K ^ -0.30896) * 2.2361) + -0.41104
# 9           1.488e-02  2.053e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.780e+03
# Head worker occupation: 6.3%
# Progress: 61 / 750 total iterations (8.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  6.535e-04  y = ((K ^ -0.30896) * 2.2361) + -0.41104
# 9           1.488e-02  2.053e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.380e+03
# Head worker occupation: 6.2%
# Progress: 67 / 750 total iterations (8.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  6.535e-04  y = ((K ^ -0.30896) * 2.2361) + -0.41104
# 9           1.488e-02  2.053e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  8.941e-07  y = (1.9767 + ((Re - K) * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.040e+03
# Head worker occupation: 6.1%
# Progress: 68 / 750 total iterations (9.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  6.535e-04  y = ((K ^ -0.30896) * 2.2361) + -0.41104
# 9           1.488e-02  2.053e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  8.941e-07  y = (1.9767 + ((Re - K) * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.780e+03
# Head worker occupation: 5.9%
# Progress: 73 / 750 total iterations (9.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  8.941e-07  y = (1.9767 + ((Re - K) * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.920e+03
# Head worker occupation: 5.7%
# Progress: 79 / 750 total iterations (10.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  8.941e-07  y = (1.9767 + ((Re - K) * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.870e+03
# Head worker occupation: 5.7%
# Progress: 80 / 750 total iterations (10.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  8.941e-07  y = (1.9767 + ((Re - K) * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.560e+03
# Head worker occupation: 5.5%
# Progress: 82 / 750 total iterations (10.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  8.941e-07  y = (1.9767 + ((Re - K) * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.830e+03
# Head worker occupation: 5.4%
# Progress: 88 / 750 total iterations (11.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  8.941e-07  y = (1.9767 + ((Re - K) * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.910e+03
# Head worker occupation: 5.4%
# Progress: 90 / 750 total iterations (12.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  8.941e-07  y = (1.9767 + ((Re - K) * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.460e+03
# Head worker occupation: 5.3%
# Progress: 93 / 750 total iterations (12.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.404e-01  1.594e+01  y = 1.6793
# 3           9.081e-02  2.178e-01  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  8.941e-07  y = (1.9767 + ((Re - K) * -4.4636e-05)) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.140e+03
# Head worker occupation: 5.3%
# Progress: 97 / 750 total iterations (12.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.703e-02  1.594e+01  y = 1.823
# 3           9.081e-02  3.315e-02  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  1.073e-06  y = ((-4.4648e-05 * (Re - K)) + 1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.570e+03
# Head worker occupation: 5.4%
# Progress: 102 / 750 total iterations (13.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.703e-02  1.594e+01  y = 1.823
# 3           9.081e-02  3.315e-02  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  1.073e-06  y = ((-4.4648e-05 * (Re - K)) + 1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.730e+03
# Head worker occupation: 5.7%
# Progress: 106 / 750 total iterations (14.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.703e-02  1.594e+01  y = 1.823
# 3           9.081e-02  3.315e-02  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  1.073e-06  y = ((-4.4648e-05 * (Re - K)) + 1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.580e+03
# Head worker occupation: 5.5%
# Progress: 108 / 750 total iterations (14.400%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.121e-04  y = ((K ^ -0.29879) + -0.21267) * 2.3184
# 9           1.488e-02  2.052e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  1.073e-06  y = ((-4.4648e-05 * (Re - K)) + 1.9767) * (K ^ -0.34894)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.850e+03
# Head worker occupation: 5.5%
# Progress: 114 / 750 total iterations (15.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.581e-04  y = (2.4062 * (K ^ -0.28866)) + -0.58047
# 9           1.488e-02  2.051e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  1.073e-06  y = ((-4.4648e-05 * (Re - K)) + 1.9767) * (K ^ -0.34894)
# 15          9.261e-03  2.214e-02  y = (K ^ -0.34839) * (2.0677 + (0.0012457 * ((Re ^ 0.63168) * ...
#                                   -1.187)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.930e+03
# Head worker occupation: 5.6%
# Progress: 118 / 750 total iterations (15.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.581e-04  y = (2.4062 * (K ^ -0.28866)) + -0.58047
# 9           1.488e-02  2.051e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  1.073e-06  y = ((-4.4648e-05 * (Re - K)) + 1.9767) * (K ^ -0.34894)
# 15          9.261e-03  2.214e-02  y = (K ^ -0.34839) * (2.0677 + (0.0012457 * ((Re ^ 0.63168) * ...
#                                   -1.187)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.930e+03
# Head worker occupation: 5.6%
# Progress: 122 / 750 total iterations (16.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.581e-04  y = (2.4062 * (K ^ -0.28866)) + -0.58047
# 9           1.488e-02  2.051e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  1.073e-06  y = ((-4.4648e-05 * (Re - K)) + 1.9767) * (K ^ -0.34894)
# 15          9.261e-03  2.214e-02  y = (K ^ -0.34839) * (2.0677 + (0.0012457 * ((Re ^ 0.63168) * ...
#                                   -1.187)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.950e+03
# Head worker occupation: 5.4%
# Progress: 125 / 750 total iterations (16.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.581e-04  y = (2.4062 * (K ^ -0.28866)) + -0.58047
# 9           1.488e-02  2.051e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.468e-03  2.980e-08  y = ((K ^ -0.34894) * (1.9767 + (-4.4636e-05 * Re))) - -4.4636...
#                                   e-05
# 14          9.468e-03  1.073e-06  y = ((-4.4648e-05 * (Re - K)) + 1.9767) * (K ^ -0.34894)
# 15          9.261e-03  2.214e-02  y = (K ^ -0.34839) * (2.0677 + (0.0012457 * ((Re ^ 0.63168) * ...
#                                   -1.187)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.920e+03
# Head worker occupation: 5.2%
# Progress: 127 / 750 total iterations (16.933%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.581e-04  y = (2.4062 * (K ^ -0.28866)) + -0.58047
# 9           1.488e-02  2.051e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.436e-03  1.705e-03  y = ((K ^ -0.42805) * ((-4.4365e-05 * Re) + 1.6025)) + 0.37062
# 15          9.261e-03  9.365e-03  y = (K ^ -0.34839) * (2.0677 + (0.0012457 * ((Re ^ 0.63168) * ...
#                                   -1.187)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.540e+03
# Head worker occupation: 5.1%
# Progress: 130 / 750 total iterations (17.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.827e-02  7.581e-04  y = (2.4062 * (K ^ -0.28866)) + -0.58047
# 9           1.488e-02  2.051e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (1.9767 + (Re * -4.4636e-05)) * (K ^ -0.34894)
# 13          9.436e-03  1.705e-03  y = ((K ^ -0.42805) * ((-4.4365e-05 * Re) + 1.6025)) + 0.37062
# 15          9.261e-03  9.365e-03  y = (K ^ -0.34839) * (2.0677 + (0.0012457 * ((Re ^ 0.63168) * ...
#                                   -1.187)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.170e+03
# Head worker occupation: 5.1%
# Progress: 135 / 750 total iterations (18.000%)
# ...
# 13          9.175e-03  1.576e-02  y = (K ^ -0.34718) * ((-0.0096179 * (Re ^ 0.45005)) + 2.1842)
# 15          9.133e-03  2.291e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.290e+03
# Head worker occupation: 2.6%
# Progress: 726 / 750 total iterations (96.800%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.175e-03  1.576e-02  y = (K ^ -0.34718) * ((-0.0096179 * (Re ^ 0.45005)) + 2.1842)
# 15          9.133e-03  2.291e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.200e+03
# Head worker occupation: 2.6%
# Progress: 729 / 750 total iterations (97.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.175e-03  1.576e-02  y = (K ^ -0.34718) * ((-0.0096179 * (Re ^ 0.45005)) + 2.1842)
# 15          9.133e-03  2.291e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.250e+03
# Head worker occupation: 2.5%
# Progress: 732 / 750 total iterations (97.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.175e-03  1.576e-02  y = (K ^ -0.34718) * ((-0.0096179 * (Re ^ 0.45005)) + 2.1842)
# 15          9.133e-03  2.291e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.240e+03
# Head worker occupation: 2.5%
# Progress: 733 / 750 total iterations (97.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.175e-03  1.576e-02  y = (K ^ -0.34718) * ((-0.0096179 * (Re ^ 0.45005)) + 2.1842)
# 15          9.133e-03  2.291e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.420e+03
# Head worker occupation: 2.6%
# Progress: 736 / 750 total iterations (98.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.175e-03  1.576e-02  y = (K ^ -0.34718) * ((-0.0096179 * (Re ^ 0.45005)) + 2.1842)
# 15          9.133e-03  2.291e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.570e+03
# Head worker occupation: 2.6%
# Progress: 739 / 750 total iterations (98.533%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.174e-03  1.580e-02  y = (2.1842 + ((Re ^ 0.44779) * -0.0098074)) * (K ^ -0.34646)
# 15          9.133e-03  2.251e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.530e+03
# Head worker occupation: 2.6%
# Progress: 740 / 750 total iterations (98.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.174e-03  1.580e-02  y = (2.1842 + ((Re ^ 0.44779) * -0.0098074)) * (K ^ -0.34646)
# 15          9.133e-03  2.251e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.490e+03
# Head worker occupation: 2.6%
# Progress: 743 / 750 total iterations (99.067%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.174e-03  1.580e-02  y = (2.1842 + ((Re ^ 0.44779) * -0.0098074)) * (K ^ -0.34646)
# 15          9.133e-03  2.251e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.410e+03
# Head worker occupation: 2.9%
# Progress: 744 / 750 total iterations (99.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.174e-03  1.580e-02  y = (2.1842 + ((Re ^ 0.44779) * -0.0098074)) * (K ^ -0.34646)
# 15          9.133e-03  2.251e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.850e+03
# Head worker occupation: 2.9%
# Progress: 747 / 750 total iterations (99.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.174e-03  1.580e-02  y = (2.1842 + ((Re ^ 0.44779) * -0.0098074)) * (K ^ -0.34646)
# 15          9.133e-03  2.251e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.040e+03
# Head worker occupation: 2.9%
# Progress: 749 / 750 total iterations (99.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           9.081e-02  1.594e+01  y = 1.901
# 3           9.081e-02  5.245e-06  y = 1.0444 - -0.85756
# 4           2.186e-02  1.424e+00  y = 2.8731 - K
# 6           1.829e-02  8.915e-02  y = (K ^ -0.37247) * 1.823
# 8           1.826e-02  8.244e-04  y = -0.95604 + (2.783 * (K ^ -0.25195))
# 9           1.488e-02  2.050e-01  y = (3.0087 - K) + (-4.0326e-05 * Re)
# 11          9.468e-03  2.260e-01  y = (K ^ -0.34892) * (1.9768 + (Re * -4.4644e-05))
# 13          9.174e-03  1.580e-02  y = (2.1842 + ((Re ^ 0.44779) * -0.0098074)) * (K ^ -0.34646)
# 15          9.133e-03  2.251e-03  y = (((-0.1061 * (Re ^ 0.21516)) + 1.9947) * (K ^ -0.34708)) /...
#                                    0.76737
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                           1.900952
# 	1        0.000005                             1.0443648 - -0.8575627
# 	2        1.423918                                      2.8730953 - K
# 	3        0.089153                       (K ^ -0.3724675) * 1.8230348
# 	4        0.000824       -0.95604193 + (2.782989 * (K ^ -0.25195268))
# 	5        0.204979               (3.00867 - K) + (-4.0325536e-5 * Re)
# 	6  >>>>  0.225977  (K ^ -0.34892437) * (1.9767534 + (Re * -4.4644...
# 	7        0.015798  (2.184246 + ((Re ^ 0.4477858) * -0.009807383))...
# 	8        0.002251  (((-0.106096566 * (Re ^ 0.2151557)) + 1.994702...
#
# 	       loss  complexity
# 	0  0.090811           1
# 	1  0.090810           3
# 	2  0.021864           4
# 	3  0.018293           6
# 	4  0.018263           8
# 	5  0.014878           9
# 	6  0.009468          11
# 	7  0.009174          13
# 	8  0.009133          15
# ]

# %%
best_equation = model.equations_.iloc[6]['equation']
print(best_equation)
# Out:
# (K ^ -0.34892437) * (1.9767534 + (Re * -4.464416e-5))

# %%
best_equation = model.equations_.iloc[7]['equation']
print(best_equation)
# Out:
# (2.184246 + ((Re ^ 0.4477858) * -0.009807383)) * (K ^ -0.34646258)

# %%
best_equation = model.equations_.iloc[8]['equation']
print(best_equation)
# Out:
# (((-0.106096566 * (Re ^ 0.2151557)) + 1.994702) * (K ^ -0.34707868)) / 0.7673668

# %%
# comparar la mejor ecuacion con el mejor modelo  de Rafael

def cdrag(S, Re):
    return S**(-0.6) + 5*Re**(-0.23)

def cdrag_gp(S, Re):
    return (S ** (-0.34892437)) * (1.9767534 + (Re * -4.464416e-5))

# %%
# Calcular cdrag_pred y cdrag_gp_pred en vectores separados
cdrag_pred = X_test.apply(lambda row: cdrag(row['K'], row['Re']), axis=1).values
cdrag_gp_pred = X_test.apply(lambda row: cdrag_gp(row['K'], row['Re']), axis=1).values

# Calcular R^2 y MSE para cdrag
r2_cdrag = r2_score(y_test['cdrag'], cdrag_pred)
mse_cdrag = mean_squared_error(y_test['cdrag'], cdrag_pred)

# Calcular MAE y MAPE para cdrag
mae_cdrag = mean_absolute_error(y_test['cdrag'], cdrag_pred)
mape_cdrag = mean_absolute_percentage_error(y_test['cdrag'], cdrag_pred)

# Calcular R^2 y MSE para cdrag_gp
r2_cdrag_gp = r2_score(y_test['cdrag'], cdrag_gp_pred)
mse_cdrag_gp = mean_squared_error(y_test['cdrag'], cdrag_gp_pred)

# Calcular MAE y MAPE para cdrag_gp
mae_cdrag_gp = mean_absolute_error(y_test['cdrag'], cdrag_gp_pred)
mape_cdrag_gp = mean_absolute_percentage_error(y_test['cdrag'], cdrag_gp_pred)

#  Mostrar Metricas 

print(f"R^2 cdrag original: {r2_cdrag}, R^2 cdrag GPLearn: {r2_cdrag_gp} ")
print(f"MSE cdrag original: {mse_cdrag}, MSE cdrag GPLearn: {mse_cdrag_gp} ")
print(f"MAE cdrag original: {mae_cdrag}, MAE cdrag GPLearn: {mae_cdrag_gp} ")
print(f"MAPE cdrag original: {mape_cdrag*100} %, MAPE cdrag GPLearn: {mape_cdrag_gp*100} % ")
# Out:
# R^2 cdrag original: 0.8904926780136748, R^2 cdrag GPLearn: 0.9005868143943995
# MSE cdrag original: 0.011588230963563853, MSE cdrag GPLearn: 0.010520054136336205
# MAE cdrag original: 0.07580331737181549, MAE cdrag GPLearn: 0.07454273938898887
# MAPE cdrag original: 3.7448292462961463 %, MAPE cdrag GPLearn: 3.723497020947485 %

# %%
# con otra otra ecuacion

def cdrag(S, Re):
    return S**(-0.6) + 5*Re**(-0.23)

def cdrag_gp(S, Re):
    return (((-0.106096566 * (Re ** 0.2151557)) + 1.994702) * (S ** (-0.34707868))) / 0.7673668

# %%
# Calcular cdrag_pred y cdrag_gp_pred en vectores separados
cdrag_pred = X_test.apply(lambda row: cdrag(row['K'], row['Re']), axis=1).values
cdrag_gp_pred = X_test.apply(lambda row: cdrag_gp(row['K'], row['Re']), axis=1).values

# Calcular R^2 y MSE para cdrag
r2_cdrag = r2_score(y_test['cdrag'], cdrag_pred)
mse_cdrag = mean_squared_error(y_test['cdrag'], cdrag_pred)

# Calcular MAE y MAPE para cdrag
mae_cdrag = mean_absolute_error(y_test['cdrag'], cdrag_pred)
mape_cdrag = mean_absolute_percentage_error(y_test['cdrag'], cdrag_pred)

# Calcular R^2 y MSE para cdrag_gp
r2_cdrag_gp = r2_score(y_test['cdrag'], cdrag_gp_pred)
mse_cdrag_gp = mean_squared_error(y_test['cdrag'], cdrag_gp_pred)

# Calcular MAE y MAPE para cdrag_gp
mae_cdrag_gp = mean_absolute_error(y_test['cdrag'], cdrag_gp_pred)
mape_cdrag_gp = mean_absolute_percentage_error(y_test['cdrag'], cdrag_gp_pred)

#  Mostrar Metricas 

print(f"R^2 cdrag original: {r2_cdrag}, R^2 cdrag GPLearn: {r2_cdrag_gp} ")
print(f"MSE cdrag original: {mse_cdrag}, MSE cdrag GPLearn: {mse_cdrag_gp} ")
print(f"MAE cdrag original: {mae_cdrag}, MAE cdrag GPLearn: {mae_cdrag_gp} ")
print(f"MAPE cdrag original: {mape_cdrag*100} %, MAPE cdrag GPLearn: {mape_cdrag_gp*100} % ")
# Out:
# R^2 cdrag original: 0.8904926780136748, R^2 cdrag GPLearn: 0.9021172954085089
# MSE cdrag original: 0.011588230963563853, MSE cdrag GPLearn: 0.010358096313287036
# MAE cdrag original: 0.07580331737181549, MAE cdrag GPLearn: 0.07415859467518686
# MAPE cdrag original: 3.7448292462961463 %, MAPE cdrag GPLearn: 3.715380046751987 %

# %% [markdown]
# ### Experimento: incorporar forma de la función de RDlS

# %%
model = PySRRegressor(
    niterations=30,
    binary_operators=["+","-","*" ,"/", "^"],
    unary_operators=["pot1(x)= x >= 0 ?  convert(typeof(x),x^(-0.6)) : convert(typeof(x), NaN)",
                    "pot2(x)=x >= 0 ?  convert(typeof(x),5*x^(-0.23)) : convert(typeof(x), NaN)"],
    extra_sympy_mappings={"pot1": lambda x:  x**(-0.6) , 
                        "pot2": lambda x: 5*x**(-0.23)},
    population_size=200,
    verbosity=1,
    maxsize=12,
    parsimony=1e-3,
    progress=True
)

#model = PySRRegressor(
#    niterations=20,
#    binary_operators=["+", "-", "*", "/", "^"],
#    unary_operators=["safe_pot1 "], 
#                    #"safe_pot2(x)=5*x^(-0.23)"],
#    extra_sympy_mappings={
#        "safe_pot1": safe_pot1},#,
        #"safe_pot2": lambda x: np.where(x > 0, 5*np.power(x,-0.23), np.nan)
    #},
#    population_size=200,
#    verbosity=1,
#    maxsize=12,
#    parsimony=1e-3,
#    progress=True
#)

#model = PySRRegressor(
#    niterations=20,
#    binary_operators=["my_safe_pot1(x, y) = x >= 0 ? x^y : convert(typeof(x), NaN)"],
#    extra_sympy_mappings={
#        "my_safe_pot1": lambda x, y: x**y if x >= 0 else float('nan')
#    },
#    progress=True
#)

model.fit(X_train, y_train)
# Out:
# d:\env\lib\site-packages\pysr\sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# d:\env\lib\site-packages\pysr\sr.py:2029: UserWarning: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (https://astroautomata.com/PySR/options/#batching). You should also reconsider if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form with symbolic regression. More datapoints will lower the search speed.
#   warnings.warn(
# Compiling Julia backend...
# d:\env\lib\site-packages\pysr\sr.py:73: UserWarning: You are using the `^` operator, but have not set up `constraints` for it. This may lead to overly complex expressions. One typical constraint is to use `constraints={..., '^': (-1, 1)}`, which will allow arbitrary-complexity base (-1) but only powers such as a constant or variable (1). For more tips, please see https://astroautomata.com/PySR/tuning/
#   warnings.warn(
# [ Info: Note: you are running with more than 10,000 datapoints. You should consider turning on batching (`options.batching`), and also if you need that many datapoints. Unless you have a large amount of noise (in which case you should smooth your dataset first), generally < 10,000 datapoints is enough to find a functional form.
# [ Info: Started!
# Expressions evaluated per second: 0.000e+00
# Head worker occupation: 0.0%
# Progress: 0 / 450 total iterations (0.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.880e+01
# Head worker occupation: 0.0%
# Progress: 1 / 450 total iterations (0.222%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.513e-01  7.971e+00  y = pot1(0.4314)
# 4           1.447e-01  2.229e-02  y = pot1(K) + K
# 5           7.413e-02  6.686e-01  y = pot1(2.0138 / pot2(K))
# 7           2.511e-02  5.412e-01  y = (K ^ (-1.3272 + 0.74762)) + 0.74762
# 8           1.011e-02  9.097e-01  y = pot2(Re) + (K ^ (-1.3272 + 0.74762))
# 10          9.815e-03  1.492e-02  y = (K ^ (-0.95007 + 0.3618)) + (pot2(Re) - -0.015117)
# 12          9.813e-03  7.615e-05  y = (K ^ (-0.064924 + -0.52337)) + (pot2(Re + 1.6396) + 0.0152...
#                                   41)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.250e+03
# Head worker occupation: 66.7%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 3 / 450 total iterations (0.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.513e-01  7.971e+00  y = pot1(0.4314)
# 3           9.081e-02  5.103e-01  y = 1.3711 + 0.53078
# 5           4.551e-02  3.455e-01  y = 1.4089 + (0.51779 ^ K)
# 7           2.511e-02  2.972e-01  y = (K ^ (-1.3272 + 0.74762)) + 0.74762
# 8           1.011e-02  9.097e-01  y = pot2(Re) + (K ^ (-1.3272 + 0.74762))
# 10          9.815e-03  1.492e-02  y = (K ^ (-0.95007 + 0.3618)) + (pot2(Re) - -0.015117)
# 12          9.813e-03  7.615e-05  y = (K ^ (-0.064924 + -0.52337)) + (pot2(Re + 1.6396) + 0.0152...
#                                   41)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.870e+03
# Head worker occupation: 1.0%
# Progress: 4 / 450 total iterations (0.889%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.513e-01  7.971e+00  y = pot1(0.4314)
# 3           9.081e-02  5.103e-01  y = 1.3711 + 0.53078
# 5           4.551e-02  3.455e-01  y = 1.4089 + (0.51779 ^ K)
# 7           2.511e-02  2.972e-01  y = (K ^ (-1.3272 + 0.74762)) + 0.74762
# 8           1.011e-02  9.097e-01  y = pot2(Re) + (K ^ (-1.3272 + 0.74762))
# 10          9.815e-03  1.492e-02  y = (K ^ (-0.95007 + 0.3618)) + (pot2(Re) - -0.015117)
# 12          9.813e-03  7.615e-05  y = (K ^ (-0.064924 + -0.52337)) + (pot2(Re + 1.6396) + 0.0152...
#                                   41)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.760e+03
# Head worker occupation: 0.3%
# Progress: 5 / 450 total iterations (1.111%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.513e-01  7.971e+00  y = pot1(0.4314)
# 3           9.081e-02  5.103e-01  y = 1.3711 + 0.53078
# 5           4.551e-02  3.455e-01  y = 1.4089 + (0.51779 ^ K)
# 6           3.212e-02  3.485e-01  y = pot1(K) - (0.55415 + -1.2596)
# 7           2.511e-02  2.459e-01  y = (K ^ (-1.3272 + 0.74762)) + 0.74762
# 8           1.011e-02  9.097e-01  y = pot2(Re) + (K ^ (-1.3272 + 0.74762))
# 10          9.815e-03  1.492e-02  y = (K ^ (-0.95007 + 0.3618)) + (pot2(Re) - -0.015117)
# 12          9.813e-03  7.615e-05  y = (K ^ (-0.064924 + -0.52337)) + (pot2(Re + 1.6396) + 0.0152...
#                                   41)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.560e+03
# Head worker occupation: 0.4%
# Progress: 8 / 450 total iterations (1.778%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.513e-01  7.971e+00  y = pot1(0.4314)
# 3           9.081e-02  5.103e-01  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.879e-02  5.887e-02  y = pot1(1.3896) + pot1(K)
# 8           9.813e-03  2.166e-01  y = pot1(pot2(Re) ^ -1.5389) + pot1(K)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.340e+03
# Head worker occupation: 0.3%
# Progress: 9 / 450 total iterations (2.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.513e-01  7.971e+00  y = pot1(0.4314)
# 3           9.081e-02  5.103e-01  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.879e-02  5.887e-02  y = pot1(1.3896) + pot1(K)
# 8           9.813e-03  2.166e-01  y = pot1(pot2(Re) ^ -1.5389) + pot1(K)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.170e+03
# Head worker occupation: 0.3%
# Progress: 10 / 450 total iterations (2.222%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.513e-01  7.971e+00  y = pot1(0.4314)
# 3           9.081e-02  5.103e-01  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.879e-02  5.887e-02  y = pot1(1.3896) + pot1(K)
# 6           1.826e-02  2.856e-02  y = (0.61302 * pot2(K)) + -1.2374
# 8           9.813e-03  3.106e-01  y = pot1(pot2(Re) ^ -1.5389) + pot1(K)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.500e+03
# Head worker occupation: 0.3%
# Progress: 12 / 450 total iterations (2.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.513e-01  7.971e+00  y = pot1(0.4314)
# 3           9.081e-02  5.103e-01  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.879e-02  5.887e-02  y = pot1(1.3896) + pot1(K)
# 6           1.826e-02  2.856e-02  y = (0.61302 * pot2(K)) + -1.2374
# 8           9.813e-03  3.106e-01  y = pot1(pot2(Re) ^ -1.5389) + pot1(K)
# 10          9.813e-03  9.835e-07  y = (pot1(K) + pot1(pot2(Re) ^ -1.5415)) - -0.00032392
# 12          9.716e-03  4.938e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.650e+03
# Head worker occupation: 0.3%
# Progress: 14 / 450 total iterations (3.111%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.513e-01  7.971e+00  y = pot1(0.4314)
# 3           9.081e-02  5.103e-01  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.879e-02  5.887e-02  y = pot1(1.3896) + pot1(K)
# 6           1.826e-02  2.856e-02  y = (0.61302 * pot2(K)) + -1.2374
# 8           9.813e-03  3.106e-01  y = pot1(pot2(Re) ^ -1.5389) + pot1(K)
# 10          9.813e-03  9.835e-07  y = (pot1(K) + pot1(pot2(Re) ^ -1.5415)) - -0.00032392
# 12          9.716e-03  4.938e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.520e+03
# Head worker occupation: 0.3%
# Progress: 15 / 450 total iterations (3.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.879e-02  5.887e-02  y = pot1(1.3896) + pot1(K)
# 6           1.826e-02  2.856e-02  y = (0.61302 * pot2(K)) + -1.2374
# 8           9.813e-03  3.106e-01  y = pot1(pot2(Re) ^ -1.5389) + pot1(K)
# 10          9.813e-03  9.835e-07  y = (pot1(K) + pot1(pot2(Re) ^ -1.5415)) - -0.00032392
# 12          9.716e-03  4.938e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.400e+03
# Head worker occupation: 0.3%
# Progress: 16 / 450 total iterations (3.556%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.002e-02  6.882e-01  y = pot1(K) + pot2(Re)
# 7           9.813e-03  1.026e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 10          9.813e-03  6.557e-07  y = (pot1(K) + pot1(pot2(Re) ^ -1.5415)) - -0.00032392
# 12          9.716e-03  4.938e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.610e+03
# Head worker occupation: 0.4%
# Progress: 19 / 450 total iterations (4.222%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.002e-02  6.882e-01  y = pot1(K) + pot2(Re)
# 7           9.813e-03  1.026e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 10          9.813e-03  6.557e-07  y = (pot1(K) + pot1(pot2(Re) ^ -1.5415)) - -0.00032392
# 12          9.716e-03  4.938e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.520e+03
# Head worker occupation: 0.4%
# Progress: 20 / 450 total iterations (4.444%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.002e-02  6.882e-01  y = pot1(K) + pot2(Re)
# 7           9.813e-03  1.026e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 10          9.813e-03  6.557e-07  y = (pot1(K) + pot1(pot2(Re) ^ -1.5415)) - -0.00032392
# 12          9.716e-03  4.938e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.460e+03
# Head worker occupation: 0.4%
# Progress: 22 / 450 total iterations (4.889%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.993e-02  1.516e+00  y = pot1(K) + 0.85462
# 5           1.002e-02  6.882e-01  y = pot1(K) + pot2(Re)
# 7           9.813e-03  1.026e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 10          9.813e-03  6.557e-07  y = (pot1(K) + pot1(pot2(Re) ^ -1.5415)) - -0.00032392
# 12          9.716e-03  4.938e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.500e+03
# Head worker occupation: 0.3%
# Progress: 23 / 450 total iterations (5.111%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = pot1(K) + 0.82085
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 7           9.813e-03  1.026e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 10          9.813e-03  6.557e-07  y = (pot1(K) + pot1(pot2(Re) ^ -1.5415)) - -0.00032392
# 12          9.716e-03  4.938e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.440e+03
# Head worker occupation: 0.4%
# Progress: 25 / 450 total iterations (5.556%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = pot1(K) + 0.82085
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 7           9.813e-03  1.026e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 10          9.813e-03  6.557e-07  y = (pot1(K) + pot1(pot2(Re) ^ -1.5415)) - -0.00032392
# 12          9.716e-03  4.938e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.830e+03
# Head worker occupation: 0.4%
# Progress: 28 / 450 total iterations (6.222%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  4.858e-05  y = pot2(Re) + (K ^ -0.59711)
# 7           9.813e-03  2.046e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 10          9.812e-03  1.689e-05  y = pot1(pot2(Re - -1.4141) ^ -1.5389) + pot1(K)
# 12          9.716e-03  4.914e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.590e+03
# Head worker occupation: 0.4%
# Progress: 31 / 450 total iterations (6.889%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  4.858e-05  y = pot2(Re) + (K ^ -0.59711)
# 7           9.813e-03  2.046e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 10          9.812e-03  1.689e-05  y = pot1(pot2(Re - -1.4141) ^ -1.5389) + pot1(K)
# 12          9.716e-03  4.914e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.880e+03
# Head worker occupation: 0.3%
# Progress: 33 / 450 total iterations (7.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  4.858e-05  y = pot2(Re) + (K ^ -0.59711)
# 7           9.813e-03  2.046e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 9           9.763e-03  2.544e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.660e+03
# Head worker occupation: 0.3%
# Progress: 35 / 450 total iterations (7.778%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  4.858e-05  y = pot2(Re) + (K ^ -0.59711)
# 7           9.813e-03  2.046e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 9           9.763e-03  2.544e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.560e+03
# Head worker occupation: 0.3%
# Progress: 37 / 450 total iterations (8.222%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  4.858e-05  y = pot2(Re) + (K ^ -0.59711)
# 7           9.813e-03  2.046e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 9           9.763e-03  2.544e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.810e+03
# Head worker occupation: 0.3%
# Progress: 40 / 450 total iterations (8.889%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  4.858e-05  y = pot2(Re) + (K ^ -0.59711)
# 7           9.813e-03  2.046e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 9           9.763e-03  2.544e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.780e+03
# Head worker occupation: 0.3%
# Progress: 42 / 450 total iterations (9.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  4.858e-05  y = pot2(Re) + (K ^ -0.59711)
# 7           9.813e-03  2.046e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 9           9.763e-03  2.544e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.950e+03
# Head worker occupation: 0.3%
# Progress: 45 / 450 total iterations (10.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  4.858e-05  y = pot2(Re) + (K ^ -0.59711)
# 7           9.813e-03  2.046e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 9           9.763e-03  2.544e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.900e+03
# Head worker occupation: 0.3%
# Progress: 46 / 450 total iterations (10.222%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  4.858e-05  y = pot2(Re) + (K ^ -0.59711)
# 7           9.813e-03  2.046e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 9           9.763e-03  2.544e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.910e+03
# Head worker occupation: 0.3%
# Progress: 48 / 450 total iterations (10.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.799e-03  1.424e-03  y = (K ^ -0.44942) + pot2(Re * K)
# 9           9.763e-03  3.664e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.630e+03
# Head worker occupation: 0.3%
# Progress: 49 / 450 total iterations (10.889%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.799e-03  1.424e-03  y = (K ^ -0.44942) + pot2(Re * K)
# 9           9.763e-03  3.664e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.480e+03
# Head worker occupation: 0.2%
# Progress: 51 / 450 total iterations (11.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.799e-03  1.424e-03  y = (K ^ -0.44942) + pot2(Re * K)
# 9           9.763e-03  3.664e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.470e+03
# Head worker occupation: 0.2%
# Progress: 52 / 450 total iterations (11.556%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.799e-03  1.424e-03  y = (K ^ -0.44942) + pot2(Re * K)
# 9           9.763e-03  3.664e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 11          9.756e-03  3.623e-04  y = pot1(K) + (pot2(Re) ^ ((0.92324 ^ K) ^ K))
# 12          9.716e-03  4.066e-03  y = (pot2((pot2(Re) ^ 0.84861) ^ -0.80215) + pot1(K)) - 4.0099
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.310e+03
# Head worker occupation: 0.2%
# Progress: 55 / 450 total iterations (12.222%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.793e-03  1.990e-03  y = (pot2(Re) ^ 0.91769) + (K ^ -0.59173)
# 9           9.763e-03  3.098e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 10          9.657e-03  1.096e-02  y = pot2(Re) + (((K - -0.15322) ^ -0.78009) + 0.12191)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.320e+03
# Head worker occupation: 0.2%
# Progress: 57 / 450 total iterations (12.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.793e-03  1.990e-03  y = (pot2(Re) ^ 0.91769) + (K ^ -0.59173)
# 9           9.763e-03  3.098e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 10          9.657e-03  1.096e-02  y = pot2(Re) + (((K - -0.15322) ^ -0.78009) + 0.12191)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.340e+03
# Head worker occupation: 0.2%
# Progress: 58 / 450 total iterations (12.889%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.793e-03  1.990e-03  y = (pot2(Re) ^ 0.91769) + (K ^ -0.59173)
# 9           9.763e-03  3.098e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 10          9.657e-03  1.096e-02  y = pot2(Re) + (((K - -0.15322) ^ -0.78009) + 0.12191)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.610e+03
# Head worker occupation: 0.2%
# Progress: 61 / 450 total iterations (13.556%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.793e-03  1.990e-03  y = (pot2(Re) ^ 0.91769) + (K ^ -0.59173)
# 9           9.763e-03  3.098e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 10          9.657e-03  1.096e-02  y = pot2(Re) + (((K - -0.15322) ^ -0.78009) + 0.12191)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.430e+03
# Head worker occupation: 0.2%
# Progress: 64 / 450 total iterations (14.222%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.793e-03  1.990e-03  y = (pot2(Re) ^ 0.91769) + (K ^ -0.59173)
# 9           9.763e-03  3.098e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 10          9.657e-03  1.096e-02  y = pot2(Re) + (((K - -0.15322) ^ -0.78009) + 0.12191)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.470e+03
# Head worker occupation: 0.2%
# Progress: 66 / 450 total iterations (14.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.793e-03  1.990e-03  y = (pot2(Re) ^ 0.91769) + (K ^ -0.59173)
# 9           9.763e-03  3.098e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 10          9.657e-03  1.096e-02  y = pot2(Re) + (((K - -0.15322) ^ -0.78009) + 0.12191)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.510e+03
# Head worker occupation: 0.2%
# Progress: 68 / 450 total iterations (15.111%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           9.979e-02  7.971e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.793e-03  1.990e-03  y = (pot2(Re) ^ 0.91769) + (K ^ -0.59173)
# 9           9.763e-03  3.098e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 10          9.657e-03  1.096e-02  y = pot2(Re) + (((K - -0.15322) ^ -0.78009) + 0.12191)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.720e+03
# Head worker occupation: 0.2%
# Progress: 71 / 450 total iterations (15.778%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 2           9.979e-02  2.496e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.793e-03  1.990e-03  y = (pot2(Re) ^ 0.91769) + (K ^ -0.59173)
# 9           9.763e-03  3.098e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 10          9.604e-03  1.645e-02  y = pot2((K * 0.88517) * Re) + (K ^ -0.44943)
# 12          9.601e-03  1.370e-04  y = pot2((K * 0.88517) * (Re - -0.90738)) + (K ^ -0.44943)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.080e+03
# Head worker occupation: 0.2%
# Progress: 74 / 450 total iterations (16.444%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 2           9.979e-02  2.496e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = pot1(K) + (pot2(Re) ^ 0.92324)
# 8           9.793e-03  1.990e-03  y = (pot2(Re) ^ 0.91769) + (K ^ -0.59173)
# 9           9.763e-03  3.098e-03  y = pot1(K) + (pot2(Re) ^ (0.92324 ^ K))
# 10          9.604e-03  1.645e-02  y = pot2((K * 0.88517) * Re) + (K ^ -0.44943)
# 12          9.601e-03  1.370e-04  y = pot2((K * 0.88517) * (Re - -0.90738)) + (K ^ -0.44943)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.070e+03
# Head worker occupation: 0.2%
# Progress: 75 / 450 total iterations (16.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.210e+00  1.594e+01  y = K
# 2           9.979e-02  2.496e+00  y = pot1(0.37296)
# 3           9.081e-02  9.427e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# ...
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.497e-03  2.752e-02  y = pot2(Re * (K - 0.086284)) + (K ^ -0.40894)
# 12          9.449e-03  2.553e-03  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.950e+03
# Head worker occupation: 0.2%
# Progress: 427 / 450 total iterations (94.889%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.497e-03  2.752e-02  y = pot2(Re * (K - 0.086284)) + (K ^ -0.40894)
# 12          9.449e-03  2.553e-03  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.750e+03
# Head worker occupation: 0.2%
# Progress: 429 / 450 total iterations (95.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.497e-03  2.752e-02  y = pot2(Re * (K - 0.086284)) + (K ^ -0.40894)
# 12          9.449e-03  2.553e-03  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.770e+03
# Head worker occupation: 0.2%
# Progress: 432 / 450 total iterations (96.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.497e-03  2.752e-02  y = pot2(Re * (K - 0.086284)) + (K ^ -0.40894)
# 12          9.449e-03  2.553e-03  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.780e+03
# Head worker occupation: 0.2%
# Progress: 434 / 450 total iterations (96.444%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.497e-03  2.752e-02  y = pot2(Re * (K - 0.086284)) + (K ^ -0.40894)
# 12          9.449e-03  2.553e-03  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.900e+03
# Head worker occupation: 0.2%
# Progress: 438 / 450 total iterations (97.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.452e-03  3.229e-02  y = (pot2(K * Re) + (K ^ -0.43623)) + 0.01992
# 12          9.449e-03  1.653e-04  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.030e+03
# Head worker occupation: 0.2%
# Progress: 442 / 450 total iterations (98.222%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.452e-03  3.229e-02  y = (pot2(K * Re) + (K ^ -0.43623)) + 0.01992
# 12          9.449e-03  1.653e-04  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.040e+03
# Head worker occupation: 0.2%
# Progress: 444 / 450 total iterations (98.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.452e-03  3.229e-02  y = (pot2(K * Re) + (K ^ -0.43623)) + 0.01992
# 12          9.449e-03  1.653e-04  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+03
# Head worker occupation: 0.2%
# Progress: 446 / 450 total iterations (99.111%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.452e-03  3.229e-02  y = (pot2(K * Re) + (K ^ -0.43623)) + 0.01992
# 12          9.449e-03  1.653e-04  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.880e+03
# Head worker occupation: 0.2%
# Progress: 448 / 450 total iterations (99.556%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.452e-03  3.229e-02  y = (pot2(K * Re) + (K ^ -0.43623)) + 0.01992
# 12          9.449e-03  1.653e-04  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.850e+03
# Head worker occupation: 0.2%
# Progress: 449 / 450 total iterations (99.778%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           2.040e-01  1.594e+01  y = 2.2384
# 2           9.449e-02  7.698e-01  y = pot1(0.36153)
# 3           9.081e-02  3.972e-02  y = 1.3711 + 0.53078
# 4           1.879e-02  1.575e+00  y = 0.82087 + pot1(K)
# 5           1.002e-02  6.293e-01  y = pot1(K) + pot2(Re)
# 6           1.002e-02  8.572e-05  y = pot2(Re) + (K ^ -0.59825)
# 7           9.813e-03  2.043e-02  y = (pot2(Re) ^ 0.92328) + pot1(K)
# 8           9.793e-03  1.992e-03  y = (pot2(Re) ^ 0.91768) + (K ^ -0.59146)
# 9           9.762e-03  3.185e-03  y = pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 10          9.452e-03  3.229e-02  y = (pot2(K * Re) + (K ^ -0.43623)) + 0.01992
# 12          9.449e-03  1.653e-04  y = (pot2((K * Re) - -2.3916) + (K ^ -0.43623)) + 0.01992
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          2.2384095
# 	1         0.769775                                   pot1(0.36152595)
# 	2         0.039724                             1.3711433 + 0.53078413
# 	3         1.575242                                0.8208654 + pot1(K)
# 	4   >>>>  0.629322                                 pot1(K) + pot2(Re)
# 	5         0.000086                       pot2(Re) + (K ^ -0.59825087)
# 	6         0.020428                   (pot2(Re) ^ 0.9232795) + pot1(K)
# 	7         0.001993             (pot2(Re) ^ 0.91768) + (K ^ -0.591458)
# 	8         0.003185               pot1(K) + (pot2(Re) ^ (0.91768 ^ K))
# 	9         0.032290   (pot2(K * Re) + (K ^ -0.43622965)) + 0.019919783
# 	10        0.000165  (pot2((K * Re) - -2.3916438) + (K ^ -0.4362296...
#
# 	        loss  complexity
# 	0   0.204030           1
# 	1   0.094490           2
# 	2   0.090810           3
# 	3   0.018794           4
# 	4   0.010016           5
# 	5   0.010015           6
# 	6   0.009813           7
# 	7   0.009793           8
# 	8   0.009762           9
# 	9   0.009452          10
# 	10  0.009449          12
# ]
